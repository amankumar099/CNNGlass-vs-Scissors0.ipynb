# %% [markdown]
# <a href="https://colab.research.google.com/github/amankumar099/CNNGlass-vs-Scissors0.ipynb/blob/main/CNNGlass_vs_Scissors0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opendatasets

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("amankumar099/glass-vs-scissors")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.12M/1.12M [00:00<00:00, 82.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/amankumar099/glass-vs-scissors/versions/1

# %%
import opendatasets as od
data = od.download("https://www.kaggle.com/datasets/amankumar099/glass-vs-scissors/data?select=WhatsApp+Image+2025-11-01+at+19.49.37_1152e41d.jpg")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: amankumar099
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/amankumar099/glass-vs-scissors
# ...
# 100%|██████████| 1.12M/1.12M [00:00<00:00, 669MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras .layers import Dense, Conv2D, MaxPooling2D, Flatten,Dropout, BatchNormalization

# %%
import os

# List the contents of the downloaded directory
download_path = './glass-vs-scissors'
if os.path.exists(download_path):
    print(f"Contents of {download_path}:")
    for item in os.listdir(download_path):
        print(item)
else:
    print(f"Directory not found: {download_path}")
# Out:
# Contents of ./glass-vs-scissors:
# WhatsApp Image 2025-11-01 at 19.49.37_1152e41d.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_cbfac043.jpg
# WhatsApp Image 2025-11-09 at 14.28.47_82df6940.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_7d52f5e7.jpg
# WhatsApp Image 2025-11-09 at 14.29.10_8bec268a.jpg
# WhatsApp Image 2025-11-09 at 14.29.10_4d292ff5.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_fc9e7983.jpg
# WhatsApp Image 2025-11-09 at 14.29.09_9c7c9cc9.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_615987c7.jpg
# WhatsApp Image 2025-11-09 at 14.28.45_abc29ada.jpg
# WhatsApp Image 2025-11-09 at 14.29.09_979718f2.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_fe77c5f9.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_872d6a45.jpg
# WhatsApp Image 2025-11-09 at 14.28.43_c314224c.jpg
# WhatsApp Image 2025-11-01 at 19.49.37_d57fc8b6.jpg
# WhatsApp Image 2025-11-09 at 14.28.46_b8a2eec5.jpg
